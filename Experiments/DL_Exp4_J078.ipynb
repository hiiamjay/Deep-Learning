# %% [markdown]
# <a href="https://colab.research.google.com/github/hiiamjay/Deep-Learning/blob/main/Experiments/DL_Exp4_J078.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Flower Recognition

# %% [markdown]
# ### Importing necessary libraries

# %%
# Ignore  the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# data visualisation and manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
 
#configure
# sets matplotlib to inline and displays graphs below the corressponding cell.
# %matplotlib inline  
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

#model selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

#preprocess.
from keras.preprocessing.image import ImageDataGenerator

#dl libraraies
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop
from keras.utils import to_categorical

# specifically for cnn
from keras.layers import Dropout, Flatten,Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
 
import tensorflow as tf
import random as rn

# specifically for manipulating zipped images and getting numpy arrays of pixel values of images.
import cv2                  
import numpy as np  
from tqdm import tqdm
import os                   
from random import shuffle  
from zipfile import ZipFile
from PIL import Image

# %%
# !wget http://upscfever.com/datasets/flowers-new.zip
# Out:
# --2021-03-31 10:28:29--  http://upscfever.com/datasets/flowers-new.zip
# Resolving upscfever.com (upscfever.com)... 104.21.90.10, 172.67.193.2, 2606:4700:3033::6815:5a0a, ...
# Connecting to upscfever.com (upscfever.com)|104.21.90.10|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://upscfever.com/datasets/flowers-new.zip [following]
# --2021-03-31 10:28:29--  https://upscfever.com/datasets/flowers-new.zip
# Connecting to upscfever.com (upscfever.com)|104.21.90.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘flowers-new.zip’
#
# flowers-new.zip         [         <=>        ]   5.74M  3.01MB/s    in 1.9s
#
# 2021-03-31 10:28:32 (3.01 MB/s) - ‘flowers-new.zip’ saved [6021364]

# %%
# !unzip flowers-new.zip
# Out:
# Archive:  flowers-new.zip
#    creating: flowers/
#    creating: flowers/daisy/
#   inflating: flowers/daisy/100080576_f52e8ee070_n.jpg
#   inflating: flowers/daisy/11642632_1e7627a2cc.jpg
#   inflating: flowers/daisy/15207766_fc2f1d692c_n.jpg
#   inflating: flowers/daisy/21652746_cc379e0eea_m.jpg
#   inflating: flowers/daisy/25360380_1a881a5648.jpg
#   inflating: flowers/daisy/43474673_7bb4465a86.jpg
#   inflating: flowers/daisy/54377391_15648e8d18.jpg
#   inflating: flowers/daisy/5547758_eea9edfd54_n.jpg
#   inflating: flowers/daisy/5673551_01d1ea993e_n.jpg
#   inflating: flowers/daisy/5673728_71b8cb57eb.jpg
#   inflating: flowers/daisy/5794835_d15905c7c8_n.jpg
#   inflating: flowers/daisy/5794839_200acd910c_n.jpg
#   inflating: flowers/daisy/99306615_739eb94b9e_m.jpg
#    creating: flowers/dandelion/
#   inflating: flowers/dandelion/10443973_aeb97513fc_m.jpg
#   inflating: flowers/dandelion/10683189_bd6e371b97.jpg
#   inflating: flowers/dandelion/10919961_0af657c4e8.jpg
#   inflating: flowers/dandelion/11405573_24a8a838cc_n.jpg
#   inflating: flowers/dandelion/11545123_50a340b473_m.jpg
#   inflating: flowers/dandelion/126012913_edf771c564_n.jpg
#   inflating: flowers/dandelion/13290033_ebd7c7abba_n.jpg
#   inflating: flowers/dandelion/13920113_f03e867ea7_m.jpg
#   inflating: flowers/dandelion/14283011_3e7452c5b2_n.jpg
#   inflating: flowers/dandelion/14829055_2a2e646a8f_m.jpg
#   inflating: flowers/dandelion/15987457_49dc11bf4b.jpg
#   inflating: flowers/dandelion/16041975_2f6c1596e5.jpg
#   inflating: flowers/dandelion/16159487_3a6615a565_n.jpg
#   inflating: flowers/dandelion/16987075_9a690a2183.jpg
#   inflating: flowers/dandelion/61242541_a04395e6bc.jpg
#   inflating: flowers/dandelion/62293290_2c463891ff_m.jpg
#   inflating: flowers/dandelion/7355522_b66e5d3078_m.jpg
#   inflating: flowers/dandelion/80846315_d997645bea_n.jpg
#   inflating: flowers/dandelion/8181477_8cb77d2e0f_n.jpg
#   inflating: flowers/dandelion/8223949_2928d3f6f6_n.jpg
#   inflating: flowers/dandelion/8223968_6b51555d2f_n.jpg
#   inflating: flowers/dandelion/8475758_4c861ab268_m.jpg
#   inflating: flowers/dandelion/8475769_3dea463364_m.jpg
#   inflating: flowers/dandelion/8684108_a85764b22d_n.jpg
#   inflating: flowers/dandelion/9818247_e2eac18894.jpg
#   inflating: flowers/dandelion/98992760_53ed1d26a9.jpg
#    creating: flowers/rose/
#   inflating: flowers/rose/102501987_3cdb8e5394_n.jpg
#   inflating: flowers/rose/110472418_87b6a3aa98_m.jpg
#   inflating: flowers/rose/118974357_0faa23cce9_n.jpg
#   inflating: flowers/rose/12240303_80d87f77a3_n.jpg
#   inflating: flowers/rose/123128873_546b8b7355_n.jpg
#   inflating: flowers/rose/145862135_ab710de93c_n.jpg
#   inflating: flowers/rose/159079265_d77a9ac920_n.jpg
#   inflating: flowers/rose/160954292_6c2b4fda65_n.jpg
#   inflating: flowers/rose/172311368_49412f881b.jpg
#   inflating: flowers/rose/174109630_3c544b8a2f.jpg
#   inflating: flowers/rose/180613732_3a7aba0b80_n.jpg
#   inflating: flowers/rose/218630974_5646dafc63_m.jpg
#   inflating: flowers/rose/22679076_bdb4c24401_m.jpg
#   inflating: flowers/rose/229488796_21ac6ee16d_n.jpg
#   inflating: flowers/rose/272481307_1eb47ba3e0_n.jpg
#   inflating: flowers/rose/295257304_de893fc94d.jpg
#   inflating: flowers/rose/298670754_f25edda891.jpg
#   inflating: flowers/rose/319298955_0c72bd36bf.jpg
#   inflating: flowers/rose/323872063_7264e7e018_m.jpg
#   inflating: flowers/rose/326541992_d542103ca8_n.jpg
#   inflating: flowers/rose/353897245_5453f35a8e.jpg
#   inflating: flowers/rose/388405293_4db1d71f21_n.jpg
#   inflating: flowers/rose/394990940_7af082cf8d_n.jpg
#   inflating: flowers/rose/410421672_563550467c.jpg
#   inflating: flowers/rose/410425647_4586667858.jpg
#   inflating: flowers/rose/99383371_37a5ac12a3_n.jpg
#    creating: flowers/sunflower/
#   inflating: flowers/sunflower/127192624_afa3d9cb84.jpg
#   inflating: flowers/sunflower/145303599_2627e23815_n.jpg
#   inflating: flowers/sunflower/147804446_ef9244c8ce_m.jpg
#   inflating: flowers/sunflower/151898652_b5f1c70b98_n.jpg
#   inflating: flowers/sunflower/164668737_aeab0cb55e_n.jpg
#   inflating: flowers/sunflower/164670176_9f5b9c7965.jpg
#   inflating: flowers/sunflower/164670455_29d8e02bbd_n.jpg
#   inflating: flowers/sunflower/24459548_27a783feda.jpg
#   inflating: flowers/sunflower/24459750_eb49f6e4cb_m.jpg
#   inflating: flowers/sunflower/26254755_1bfc494ef1_n.jpg
#   inflating: flowers/sunflower/27465811_9477c9d044.jpg
#   inflating: flowers/sunflower/27466794_57e4fe5656.jpg
#   inflating: flowers/sunflower/29972905_4cc537ff4b_n.jpg
#   inflating: flowers/sunflower/35477171_13cb52115c_n.jpg
#   inflating: flowers/sunflower/39271782_b4335d09ae_n.jpg
#   inflating: flowers/sunflower/40410686_272bc66faf_m.jpg
#   inflating: flowers/sunflower/40410814_fba3837226_n.jpg
#   inflating: flowers/sunflower/40410963_3ac280f23a_n.jpg
#   inflating: flowers/sunflower/40411019_526f3fc8d9_m.jpg
#   inflating: flowers/sunflower/40411100_7fbe10ec0f_n.jpg
#   inflating: flowers/sunflower/44079668_34dfee3da1_n.jpg
#   inflating: flowers/sunflower/45045003_30bbd0a142_m.jpg
#   inflating: flowers/sunflower/45045005_57354ee844.jpg
#   inflating: flowers/sunflower/50987813_7484bfbcdf.jpg
#   inflating: flowers/sunflower/58636535_bc53ef0a21_m.jpg
#   inflating: flowers/sunflower/6953297_8576bf4ea3.jpg
#    creating: flowers/tulip/
#   inflating: flowers/tulip/100930342_92e8746431_n.jpg
#   inflating: flowers/tulip/107693873_86021ac4ea_n.jpg
#   inflating: flowers/tulip/10791227_7168491604.jpg
#   inflating: flowers/tulip/110147301_ad921e2828.jpg
#   inflating: flowers/tulip/112334842_3ecf7585dd.jpg
#   inflating: flowers/tulip/112428665_d8f3632f36_n.jpg
#   inflating: flowers/tulip/112428919_f0c5ad7d9d_n.jpg
#   inflating: flowers/tulip/112650879_82adc2cc04_n.jpg
#   inflating: flowers/tulip/112651128_7b5d39a346_m.jpg
#   inflating: flowers/tulip/112951022_4892b1348b_n.jpg
#   inflating: flowers/tulip/112951086_150a59d499_n.jpg
#   inflating: flowers/tulip/113291410_1bdc718ed8_n.jpg
#   inflating: flowers/tulip/113902743_8f537f769b_n.jpg
#   inflating: flowers/tulip/113960470_38fab8f2fb_m.jpg
#   inflating: flowers/tulip/116343334_9cb4acdc57_n.jpg
#   inflating: flowers/tulip/11746080_963537acdc.jpg
#   inflating: flowers/tulip/11746276_de3dec8201.jpg
#   inflating: flowers/tulip/11746367_d23a35b085_n.jpg
#   inflating: flowers/tulip/11746452_5bc1749a36.jpg
#   inflating: flowers/tulip/11746548_26b3256922_n.jpg
#   inflating: flowers/tulip/122450705_9885fff3c4_n.jpg
#   inflating: flowers/tulip/130685040_3c2fcec63e_n.jpg
#   inflating: flowers/tulip/130685347_afbffe3afa_n.jpg
#   inflating: flowers/tulip/14957470_6a8c272a87_m.jpg
#   inflating: flowers/tulip/38287568_627de6ca20.jpg
#   inflating: flowers/tulip/65347450_53658c63bd_n.jpg

# %% [markdown]
# ### Making the functions to get the training and validation set from the Images

# %%
X=[]
Z=[]
IMG_SIZE=150
FLOWER_DAISY_DIR='flowers/daisy'
FLOWER_SUNFLOWER_DIR='flowers/sunflower'
FLOWER_TULIP_DIR='flowers/tulip'
FLOWER_DANDI_DIR='flowers/dandelion'
FLOWER_ROSE_DIR='flowers/rose'

# %%
flower_dirs = [FLOWER_DAISY_DIR, FLOWER_SUNFLOWER_DIR, FLOWER_TULIP_DIR, FLOWER_DANDI_DIR, FLOWER_ROSE_DIR]

# %%
flowers = ['Daisy', 'Sunflower', 'Tulip', 'Dandelion', 'Rose']

# %%
def generate_images(flower, DIR, num=10):
  for img in tqdm(os.listdir(DIR)):
    img = cv2.imread(DIR + '/' + img)
    img = img.reshape((1,) + img.shape)

    gen_datagen = ImageDataGenerator(
          rotation_range=90,  
          zoom_range = 0.3, 
          width_shift_range=0.2,
          height_shift_range=0.2,
          horizontal_flip=True,
          vertical_flip=True,
          brightness_range=[0.5,1.5],
          shear_range=0.2
    )

    for idx, image_save in enumerate((gen_datagen.flow(img, 
                                                      batch_size=1, 
                                                      save_to_dir = DIR + '/', save_prefix=flower,
                                                      save_format='jpg'))):
      if idx == 30:
        break

# %%
for flower, flower_dir in zip(flowers, flower_dirs):
  generate_images(flower, flower_dir)
# Out:
# 100%|██████████| 13/13 [00:11<00:00,  1.14it/s]
# 100%|██████████| 26/26 [00:22<00:00,  1.17it/s]
# 100%|██████████| 26/26 [00:22<00:00,  1.18it/s]
# 100%|██████████| 26/26 [00:22<00:00,  1.14it/s]
# 100%|██████████| 26/26 [00:22<00:00,  1.17it/s]

# %%
len(os.listdir(FLOWER_DAISY_DIR))
# Out:
# 409

# %%
def make_train_data(flower_type,DIR):
    for img in os.listdir(DIR):
        
        path = os.path.join(DIR,img)
        img = cv2.imread(path,cv2.IMREAD_COLOR)
        img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))
        
        X.append(np.array(img))
        Z.append(str(flower_type))

# %%
for flower, flower_dir in zip(flowers, flower_dirs):
  make_train_data(flower, flower_dir)

# %%
for flower_dir in flower_dirs:
  print(str(len(os.listdir(flower_dir))) + flower_dir)
# Out:
# 409flowers/daisy
# 800flowers/sunflower
# 796flowers/tulip
# 804flowers/dandelion
# 798flowers/rose

# %%
fig, ax = plt.subplots(5,5)
fig.set_size_inches(9,9)

for i in range(5):
  for j in range(5):

    ax[i][j].set_xticks([])
    ax[i][j].set_yticks([])

    l = rn.randint(0,len(Z))
    ax[i][j].imshow(X[l])
    ax[i][j].title.set_text('Flower: '+ Z[l])
    
plt.tight_layout()

# %%
len(X)
# Out:
# 3607

# %%
len(Z)
# Out:
# 3607

# %% [markdown]
# ### Label Encoding the Y array (i.e. Daisy->0, Rose->1 etc...) & then One Hot Encoding

# %%
le=LabelEncoder()
Y=le.fit_transform(Z)
Y=to_categorical(Y,5)
X=np.array(X)
X=X/255

# %% [markdown]
# ### Splitting into Training and Validation Sets

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

# %% [markdown]
# ### Setting the Random Seeds

# %%
np.random.seed(42)
rn.seed(42)

# %% [markdown]
# ### Building the ANN

# %%
import tensorflow as tf 
from tensorflow import keras 
import matplotlib.pyplot as plt

# %%
model = keras.Sequential([keras.layers.Flatten(input_shape=(150,150,3)),
                          keras.layers.Dense(128,activation = tf.nn.relu, kernel_regularizer=tf.keras.regularizers.l2(0.001)),
                          keras.layers.Dense(64,activation = tf.nn.relu,kernel_regularizer=tf.keras.regularizers.l2(0.001)),
                          keras.layers.Dense(32,activation = tf.nn.relu,kernel_regularizer=tf.keras.regularizers.l2(0.001)),
                          keras.layers.Dense(5)])

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(),
              loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Building ANN Model

# %%
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

rd = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)
es = EarlyStopping(monitor='val_loss', min_delta=0, patience=55, verbose=1, mode='auto')
filepath='regularized_weight_{epoch:02d}_{val_loss:.2f}.h5'
mc = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

# %%
history = model.fit(x_train,y_train, batch_size=100, validation_split=0.2, epochs = 100, verbose = 2, callbacks=[rd, es, mc])
# Out:
# Epoch 1/100
# 22/22 - 4s - loss: 7.7161 - accuracy: 0.2213 - val_loss: 2.8946 - val_accuracy: 0.4122
#
# Epoch 00001: val_loss improved from inf to 2.89463, saving model to regularized_weight_01_2.89.h5
# Epoch 2/100
# 22/22 - 0s - loss: 2.4521 - accuracy: 0.3734 - val_loss: 1.7413 - val_accuracy: 0.4769
#
# Epoch 00002: val_loss improved from 2.89463 to 1.74129, saving model to regularized_weight_02_1.74.h5
# Epoch 3/100
# 22/22 - 0s - loss: 1.7789 - accuracy: 0.4584 - val_loss: 1.6628 - val_accuracy: 0.5028
#
# Epoch 00003: val_loss improved from 1.74129 to 1.66281, saving model to regularized_weight_03_1.66.h5
# Epoch 4/100
# 22/22 - 0s - loss: 1.5252 - accuracy: 0.5231 - val_loss: 1.9942 - val_accuracy: 0.4473
#
# Epoch 00004: val_loss did not improve from 1.66281
# Epoch 5/100
# 22/22 - 0s - loss: 1.4465 - accuracy: 0.5305 - val_loss: 1.8418 - val_accuracy: 0.4695
#
# Epoch 00005: val_loss did not improve from 1.66281
# Epoch 6/100
# 22/22 - 0s - loss: 1.5108 - accuracy: 0.5180 - val_loss: 1.6915 - val_accuracy: 0.5305
#
# Epoch 00006: val_loss did not improve from 1.66281
# Epoch 7/100
# 22/22 - 0s - loss: 1.4259 - accuracy: 0.5351 - val_loss: 1.3805 - val_accuracy: 0.5342
#
# Epoch 00007: val_loss improved from 1.66281 to 1.38050, saving model to regularized_weight_07_1.38.h5
# Epoch 8/100
# 22/22 - 0s - loss: 1.2174 - accuracy: 0.6040 - val_loss: 1.4436 - val_accuracy: 0.5157
#
# Epoch 00008: val_loss did not improve from 1.38050
# Epoch 9/100
# 22/22 - 0s - loss: 1.1877 - accuracy: 0.6141 - val_loss: 1.4839 - val_accuracy: 0.5471
#
# Epoch 00009: val_loss did not improve from 1.38050
# Epoch 10/100
# 22/22 - 0s - loss: 1.1924 - accuracy: 0.6155 - val_loss: 1.5292 - val_accuracy: 0.4806
#
# Epoch 00010: val_loss did not improve from 1.38050
# Epoch 11/100
# 22/22 - 0s - loss: 1.1582 - accuracy: 0.6211 - val_loss: 1.3125 - val_accuracy: 0.5508
#
# Epoch 00011: val_loss improved from 1.38050 to 1.31254, saving model to regularized_weight_11_1.31.h5
# Epoch 12/100
# 22/22 - 0s - loss: 1.3906 - accuracy: 0.5762 - val_loss: 1.4011 - val_accuracy: 0.5434
#
# Epoch 00012: val_loss did not improve from 1.31254
# Epoch 13/100
# 22/22 - 0s - loss: 1.3111 - accuracy: 0.5901 - val_loss: 1.7928 - val_accuracy: 0.4621
#
# Epoch 00013: val_loss did not improve from 1.31254
# Epoch 14/100
# 22/22 - 0s - loss: 1.1926 - accuracy: 0.5915 - val_loss: 1.5284 - val_accuracy: 0.5453
#
# Epoch 00014: val_loss did not improve from 1.31254
# Epoch 15/100
# 22/22 - 0s - loss: 1.1665 - accuracy: 0.6155 - val_loss: 1.4042 - val_accuracy: 0.5213
#
# Epoch 00015: val_loss did not improve from 1.31254
# Epoch 16/100
# 22/22 - 0s - loss: 0.9947 - accuracy: 0.6913 - val_loss: 1.3924 - val_accuracy: 0.5102
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00016: val_loss did not improve from 1.31254
# Epoch 17/100
# 22/22 - 0s - loss: 0.8683 - accuracy: 0.7468 - val_loss: 1.2476 - val_accuracy: 0.5582
#
# Epoch 00017: val_loss improved from 1.31254 to 1.24760, saving model to regularized_weight_17_1.25.h5
# Epoch 18/100
# 22/22 - 0s - loss: 0.8299 - accuracy: 0.7731 - val_loss: 1.2621 - val_accuracy: 0.5379
#
# Epoch 00018: val_loss did not improve from 1.24760
# Epoch 19/100
# 22/22 - 0s - loss: 0.8200 - accuracy: 0.7796 - val_loss: 1.2428 - val_accuracy: 0.5749
#
# Epoch 00019: val_loss improved from 1.24760 to 1.24284, saving model to regularized_weight_19_1.24.h5
# Epoch 20/100
# 22/22 - 0s - loss: 0.8190 - accuracy: 0.7726 - val_loss: 1.2624 - val_accuracy: 0.5453
#
# Epoch 00020: val_loss did not improve from 1.24284
# Epoch 21/100
# 22/22 - 0s - loss: 0.8170 - accuracy: 0.7763 - val_loss: 1.2517 - val_accuracy: 0.5786
#
# Epoch 00021: val_loss did not improve from 1.24284
# Epoch 22/100
# 22/22 - 0s - loss: 0.8149 - accuracy: 0.7796 - val_loss: 1.2594 - val_accuracy: 0.5582
#
# Epoch 00022: val_loss did not improve from 1.24284
# Epoch 23/100
# 22/22 - 0s - loss: 0.8043 - accuracy: 0.7879 - val_loss: 1.2383 - val_accuracy: 0.5767
#
# Epoch 00023: val_loss improved from 1.24284 to 1.23834, saving model to regularized_weight_23_1.24.h5
# Epoch 24/100
# 22/22 - 0s - loss: 0.7978 - accuracy: 0.7948 - val_loss: 1.2455 - val_accuracy: 0.5638
#
# Epoch 00024: val_loss did not improve from 1.23834
# Epoch 25/100
# 22/22 - 0s - loss: 0.7979 - accuracy: 0.8027 - val_loss: 1.2471 - val_accuracy: 0.5675
#
# Epoch 00025: val_loss did not improve from 1.23834
# Epoch 26/100
# 22/22 - 0s - loss: 0.7941 - accuracy: 0.7934 - val_loss: 1.2356 - val_accuracy: 0.5712
#
# Epoch 00026: val_loss improved from 1.23834 to 1.23557, saving model to regularized_weight_26_1.24.h5
# Epoch 27/100
# 22/22 - 0s - loss: 0.7874 - accuracy: 0.7981 - val_loss: 1.2298 - val_accuracy: 0.5786
#
# Epoch 00027: val_loss improved from 1.23557 to 1.22981, saving model to regularized_weight_27_1.23.h5
# Epoch 28/100
# 22/22 - 0s - loss: 0.7830 - accuracy: 0.8059 - val_loss: 1.2331 - val_accuracy: 0.5767
#
# Epoch 00028: val_loss did not improve from 1.22981
# Epoch 29/100
# 22/22 - 0s - loss: 0.7823 - accuracy: 0.8045 - val_loss: 1.2246 - val_accuracy: 0.5878
#
# Epoch 00029: val_loss improved from 1.22981 to 1.22458, saving model to regularized_weight_29_1.22.h5
# Epoch 30/100
# 22/22 - 0s - loss: 0.7808 - accuracy: 0.7990 - val_loss: 1.2228 - val_accuracy: 0.5841
#
# Epoch 00030: val_loss improved from 1.22458 to 1.22282, saving model to regularized_weight_30_1.22.h5
# Epoch 31/100
# 22/22 - 0s - loss: 0.7743 - accuracy: 0.8091 - val_loss: 1.2173 - val_accuracy: 0.5841
#
# Epoch 00031: val_loss improved from 1.22282 to 1.21732, saving model to regularized_weight_31_1.22.h5
# Epoch 32/100
# 22/22 - 0s - loss: 0.7745 - accuracy: 0.8087 - val_loss: 1.2490 - val_accuracy: 0.5712
#
# Epoch 00032: val_loss did not improve from 1.21732
# Epoch 33/100
# 22/22 - 0s - loss: 0.7677 - accuracy: 0.8073 - val_loss: 1.2257 - val_accuracy: 0.5730
#
# Epoch 00033: val_loss did not improve from 1.21732
# Epoch 34/100
# 22/22 - 0s - loss: 0.7565 - accuracy: 0.8207 - val_loss: 1.2289 - val_accuracy: 0.5749
#
# Epoch 00034: val_loss did not improve from 1.21732
# Epoch 35/100
# 22/22 - 0s - loss: 0.7505 - accuracy: 0.8244 - val_loss: 1.2370 - val_accuracy: 0.5860
#
# Epoch 00035: val_loss did not improve from 1.21732
# Epoch 36/100
# 22/22 - 0s - loss: 0.7532 - accuracy: 0.8202 - val_loss: 1.2147 - val_accuracy: 0.5841
#
# Epoch 00036: val_loss improved from 1.21732 to 1.21475, saving model to regularized_weight_36_1.21.h5
# Epoch 37/100
# 22/22 - 0s - loss: 0.7396 - accuracy: 0.8226 - val_loss: 1.2343 - val_accuracy: 0.5767
#
# Epoch 00037: val_loss did not improve from 1.21475
# Epoch 38/100
# 22/22 - 0s - loss: 0.7388 - accuracy: 0.8327 - val_loss: 1.2225 - val_accuracy: 0.5823
#
# Epoch 00038: val_loss did not improve from 1.21475
# Epoch 39/100
# 22/22 - 0s - loss: 0.7384 - accuracy: 0.8290 - val_loss: 1.2172 - val_accuracy: 0.5804
#
# Epoch 00039: val_loss did not improve from 1.21475
# Epoch 40/100
# 22/22 - 0s - loss: 0.7265 - accuracy: 0.8387 - val_loss: 1.2497 - val_accuracy: 0.5601
#
# Epoch 00040: val_loss did not improve from 1.21475
# Epoch 41/100
# 22/22 - 0s - loss: 0.7252 - accuracy: 0.8290 - val_loss: 1.2171 - val_accuracy: 0.5896
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00041: val_loss did not improve from 1.21475
# Epoch 42/100
# 22/22 - 0s - loss: 0.7130 - accuracy: 0.8429 - val_loss: 1.2168 - val_accuracy: 0.5786
#
# Epoch 00042: val_loss did not improve from 1.21475
# Epoch 43/100
# 22/22 - 0s - loss: 0.7119 - accuracy: 0.8443 - val_loss: 1.2127 - val_accuracy: 0.5804
#
# Epoch 00043: val_loss improved from 1.21475 to 1.21273, saving model to regularized_weight_43_1.21.h5
# Epoch 44/100
# 22/22 - 0s - loss: 0.7110 - accuracy: 0.8410 - val_loss: 1.2163 - val_accuracy: 0.5749
#
# Epoch 00044: val_loss did not improve from 1.21273
# Epoch 45/100
# 22/22 - 0s - loss: 0.7108 - accuracy: 0.8447 - val_loss: 1.2141 - val_accuracy: 0.5841
#
# Epoch 00045: val_loss did not improve from 1.21273
# Epoch 46/100
# 22/22 - 0s - loss: 0.7104 - accuracy: 0.8429 - val_loss: 1.2132 - val_accuracy: 0.5804
#
# Epoch 00046: val_loss did not improve from 1.21273
# Epoch 47/100
# 22/22 - 0s - loss: 0.7096 - accuracy: 0.8461 - val_loss: 1.2138 - val_accuracy: 0.5804
#
# Epoch 00047: val_loss did not improve from 1.21273
# Epoch 48/100
# 22/22 - 0s - loss: 0.7097 - accuracy: 0.8396 - val_loss: 1.2175 - val_accuracy: 0.5841
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00048: val_loss did not improve from 1.21273
# Epoch 49/100
# 22/22 - 0s - loss: 0.7078 - accuracy: 0.8475 - val_loss: 1.2155 - val_accuracy: 0.5823
#
# Epoch 00049: val_loss did not improve from 1.21273
# Epoch 50/100
# 22/22 - 0s - loss: 0.7074 - accuracy: 0.8466 - val_loss: 1.2146 - val_accuracy: 0.5804
#
# Epoch 00050: val_loss did not improve from 1.21273
# Epoch 51/100
# 22/22 - 0s - loss: 0.7073 - accuracy: 0.8475 - val_loss: 1.2136 - val_accuracy: 0.5804
#
# Epoch 00051: val_loss did not improve from 1.21273
# Epoch 52/100
# 22/22 - 0s - loss: 0.7073 - accuracy: 0.8461 - val_loss: 1.2136 - val_accuracy: 0.5804
#
# Epoch 00052: val_loss did not improve from 1.21273
# Epoch 53/100
# 22/22 - 0s - loss: 0.7072 - accuracy: 0.8457 - val_loss: 1.2138 - val_accuracy: 0.5823
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 00053: val_loss did not improve from 1.21273
# Epoch 54/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8466 - val_loss: 1.2138 - val_accuracy: 0.5823
#
# Epoch 00054: val_loss did not improve from 1.21273
# Epoch 55/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8466 - val_loss: 1.2138 - val_accuracy: 0.5823
#
# Epoch 00055: val_loss did not improve from 1.21273
# Epoch 56/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8466 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00056: val_loss did not improve from 1.21273
# Epoch 57/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8466 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00057: val_loss did not improve from 1.21273
# Epoch 58/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
#
# Epoch 00058: val_loss did not improve from 1.21273
# Epoch 59/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8466 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00059: val_loss did not improve from 1.21273
# Epoch 60/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8466 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00060: val_loss did not improve from 1.21273
# Epoch 61/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8466 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00061: val_loss did not improve from 1.21273
# Epoch 62/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8466 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00062: val_loss did not improve from 1.21273
# Epoch 63/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
#
# Epoch 00063: val_loss did not improve from 1.21273
# Epoch 64/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00064: val_loss did not improve from 1.21273
# Epoch 65/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00065: val_loss did not improve from 1.21273
# Epoch 66/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00066: val_loss did not improve from 1.21273
# Epoch 67/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00067: val_loss did not improve from 1.21273
# Epoch 68/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
#
# Epoch 00068: val_loss did not improve from 1.21273
# Epoch 69/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00069: val_loss did not improve from 1.21273
# Epoch 70/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00070: val_loss did not improve from 1.21273
# Epoch 71/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00071: val_loss did not improve from 1.21273
# Epoch 72/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00072: val_loss did not improve from 1.21273
# Epoch 73/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-11.
#
# Epoch 00073: val_loss did not improve from 1.21273
# Epoch 74/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00074: val_loss did not improve from 1.21273
# Epoch 75/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00075: val_loss did not improve from 1.21273
# Epoch 76/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00076: val_loss did not improve from 1.21273
# Epoch 77/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00077: val_loss did not improve from 1.21273
# Epoch 78/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-12.
#
# Epoch 00078: val_loss did not improve from 1.21273
# Epoch 79/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00079: val_loss did not improve from 1.21273
# Epoch 80/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00080: val_loss did not improve from 1.21273
# Epoch 81/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00081: val_loss did not improve from 1.21273
# Epoch 82/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00082: val_loss did not improve from 1.21273
# Epoch 83/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 1.0000001044244145e-13.
#
# Epoch 00083: val_loss did not improve from 1.21273
# Epoch 84/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00084: val_loss did not improve from 1.21273
# Epoch 85/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00085: val_loss did not improve from 1.21273
# Epoch 86/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00086: val_loss did not improve from 1.21273
# Epoch 87/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00087: val_loss did not improve from 1.21273
# Epoch 88/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 1.0000001179769417e-14.
#
# Epoch 00088: val_loss did not improve from 1.21273
# Epoch 89/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00089: val_loss did not improve from 1.21273
# Epoch 90/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00090: val_loss did not improve from 1.21273
# Epoch 91/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00091: val_loss did not improve from 1.21273
# Epoch 92/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00092: val_loss did not improve from 1.21273
# Epoch 93/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 1.0000001518582595e-15.
#
# Epoch 00093: val_loss did not improve from 1.21273
# Epoch 94/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00094: val_loss did not improve from 1.21273
# Epoch 95/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00095: val_loss did not improve from 1.21273
# Epoch 96/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00096: val_loss did not improve from 1.21273
# Epoch 97/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00097: val_loss did not improve from 1.21273
# Epoch 98/100
# 22/22 - 0s - loss: 0.7070 - accuracy: 0.8470 - val_loss: 1.2137 - val_accuracy: 0.5823
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 1.0000001095066122e-16.
#
# Epoch 00098: val_loss did not improve from 1.21273
# Epoch 00098: early stopping

# %%
pred = model.evaluate(x_test, y_test)
# Out:
# 29/29 [==============================] - 0s 6ms/step - loss: 1.2272 - accuracy: 0.5743

# %% [markdown]
# #Add softmax to get predictions

# %%
final_model = tf.keras.Sequential([
                                   model,
                                   tf.keras.layers.Softmax()
])

# %%
predictions = final_model.predict_classes(x_test)

# %% [markdown]
# ### Saving Model

# %%
# save the model to disk
final_model.save('final_model2.h5')

# %% [markdown]
# ### Loading Model

# %%
from tensorflow import keras
model = keras.models.load_model('/content/final_model2.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 5)                 8650629
# _________________________________________________________________
# softmax (Softmax)            (None, 5)                 0
# =================================================================
# Total params: 8,650,629
# Trainable params: 8,650,629
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Deployment

# %%
# !pip install flask gevent requests pillow
# Out:
# Requirement already satisfied: flask in /usr/local/lib/python3.7/dist-packages (1.1.2)
# Collecting gevent
#   Downloading https://files.pythonhosted.org/packages/3e/85/df3d1fd2b60a87455475f93012861b76a411d27ba4a0859939adbe2c9dc3/gevent-21.1.2-cp37-cp37m-manylinux2010_x86_64.whl (5.6MB)
#      |████████████████████████████████| 5.6MB 7.6MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (7.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.7/dist-packages (from flask) (1.0.1)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.7/dist-packages (from flask) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from flask) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.7/dist-packages (from flask) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from gevent) (54.2.0)
# Collecting zope.event
#   Downloading https://files.pythonhosted.org/packages/9e/85/b45408c64f3b888976f1d5b37eed8d746b8d5729a66a49ec846fda27d371/zope.event-4.5.0-py2.py3-none-any.whl
# Requirement already satisfied: greenlet<2.0,>=0.4.17; platform_python_implementation == "CPython" in /usr/local/lib/python3.7/dist-packages (from gevent) (1.0.0)
# Collecting zope.interface
#   Downloading https://files.pythonhosted.org/packages/89/57/8a68360d697cf9159cba5ee35f2d25bdcda33883e8b5a997714a191a0b11/zope.interface-5.3.0-cp37-cp37m-manylinux2010_x86_64.whl (248kB)
#      |████████████████████████████████| 256kB 49.6MB/s
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.10.1->flask) (1.1.1)
# Installing collected packages: zope.event, zope.interface, gevent
# Successfully installed gevent-21.1.2 zope.event-4.5.0 zope.interface-5.3.0

# %% [markdown]
# Creat a file ProcFile

# %%
procfile = 'web: gunicorn app:app'
procfiles= open("/content/Procfile","w")
procfiles.write(procfile)
procfiles.close()

# %% [markdown]
# #Install flask and ngrok

# %%
# !pip install flask-ngrok
from flask_ngrok import run_with_ngrok
from flask import Flask
# Out:
# Collecting flask-ngrok
#   Downloading https://files.pythonhosted.org/packages/af/6c/f54cb686ad1129e27d125d182f90f52b32f284e6c8df58c1bae54fa1adbc/flask_ngrok-0.0.25-py3-none-any.whl
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (1.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (2.23.0)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.1.0)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (2.10)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.10.1->Flask>=0.8->flask-ngrok) (1.1.1)
# Installing collected packages: flask-ngrok
# Successfully installed flask-ngrok-0.0.25

# %% [markdown]
# #Webpage

# %%
a = '''
<!doctype html>
<html lang="en">
<head>
<title>My flower recognizer</title>
</head> 
  <body>
 
          <h3>Image Recognition Server</h3><br/>
       
      <form action="" method="post" enctype=multipart/form-data>
        <input type=file name="flowers"><br/>
        
        <p>daisy = 0</p><br/>
        <p>dandelion = 1</p><br/>
        <p>rose = 2</p><br/>
        <p>sunflower = 3</p><br/>
        <p>tulip = 4</p><br/>
        <p>Enter flower number in text box</p><br/>
        <input type=text name="flower_name">

        <input type=submit value=Upload>
    </form>
    {{label}}  
     
  </body>
  </html>
  '''

# %%
# !mkdir '/content/templates'
# !mkdir '/content/uploads'
# !mkdir '/content/uploads/daisy'
# !mkdir '/content/uploads/dandelion'
# !mkdir '/content/uploads/rose'
# !mkdir '/content/uploads/sunflower'
# !mkdir '/content/uploads/tulip'

Html_file = open("/content/templates/index.html", "w")
Html_file.write(a)
Html_file.close()

# %% [markdown]
# #Deploy model

# %%
import os
from flask import Flask, render_template, request
from keras.preprocessing import image
from keras.preprocessing.image import load_img, img_to_array

app = Flask(__name__)
run_with_ngrok(app)
app.config['UPLOADS'] = 'uploads'


def load_mymodel():
    global mymodel
    mymodel = keras.models.load_model('/content/final_model2.h5')
    final_model = tf.keras.Sequential([
                                   mymodel,
                                   tf.keras.layers.Softmax()
    ])
    

@app.route('/')
def home():
    return render_template('index.html')

def predictions(file):
    img = image.load_img(file, target_size=(150,150), color_mode="rgb")
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    ans = final_model.predict_classes(img)
    return ans


@app.route('/', methods=['POST'])
def upload_files():
    file = request.files['flowers']
    flowerslabels = request.form['flower_name']
    print(type(flowerslabels))
    if int(flowerslabels) == 0:
      flowerslabels = 'daisy'
      filepath = os.path.join(app.config['UPLOADS'], flowerslabels, file.filename)
      file.save(filepath)
    elif int(flowerslabels) == 1:
      flowerslabels = 'dandelion'
      filepath = os.path.join(app.config['UPLOADS'], flowerslabels, file.filename)
      file.save(filepath)
    elif int(flowerslabels) == 2:
      flowerslabels = 'rose'
      filepath = os.path.join(app.config['UPLOADS'], flowerslabels, file.filename)
      file.save(filepath)
    elif int(flowerslabels) == 3:
      flowerslabels = 'sunflower'
      filepath = os.path.join(app.config['UPLOADS'], flowerslabels, file.filename)
      file.save(filepath)
    else:
      flowerslabels = 'tulip'
      filepath = os.path.join(app.config['UPLOADS'], flowerslabels, file.filename)
      file.save(filepath)



    output = predictions(filepath)

    if output.astype('int32') == 0:
      output = 'daisy'
    elif output.astype('int32') == 1:
      output = 'dandelion'
    elif output.astype('int32') == 2:
      output = 'rose'
    elif output.astype('int32') == 3:
      output = 'sunflower'
    else:
      output = 'tulip'

    return render_template('index.html', label=output)



if __name__=='__main__':
    load_mymodel()
    app.run()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://4ee2e2206a84.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
